# %% [markdown]
# # UniNa - Data Mining 20/21 - MiniContest n3
# ## Parasite Eggs Identification
# https://www.kaggle.com/c/unina-data-mining-2021-minicontest-n3/overview

# %% [markdown]
# # 1. Introduction
# This notebook shows the solution proposed for the third Mini-Contest of the Data Mining course of University of Naples Federico II.
#
# The contest aims at the detection of parasite eggs in microscopic images.
# It is a **bynary classification** problem, since the model must predict one of the following classes:
# - *uovo* (egg): meaning that the image contains a parasite egg;
# - *empty*, meaning that the image does not contain any egg.
#
# The prediction model has to be able to correctly predict the presence of an egg for each image in the test set. The performance measure to maximize is the **accuracy** of the model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.1. Import relevant modules

# %%
# Data Analysis
import pandas as pd

# Data Visualization
from matplotlib import pyplot as plt
import seaborn as sns

# Machine Learning
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
from sklearn.metrics import confusion_matrix

# Utilities
import numpy as np
import time
import os
import shutil
import copy
import random
from PIL import Image

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 1.2. Read the dataset

# %%
# !cp drive/My\ Drive/Colab\ Notebooks/DM\ -\ Collab/Mini\ Contest\ 3/dataset/test.rar /content/
# !cp drive/My\ Drive/Colab\ Notebooks/DM\ -\ Collab/Mini\ Contest\ 3/dataset/train.rar /content/

# !unrar x test.rar dataset/ 
# !unrar x train.rar dataset/
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from test.rar
#
# Creating    dataset                                                   OK
# Creating    dataset/test                                              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from train.rar
#
# Creating    dataset/train                                             OK
# Creating    dataset/train/empty                                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    dataset/train/uovo                                        OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# ### 1.2.1. Training set

# %%
train_empty = os.listdir('dataset/train/empty')
train_egg = os.listdir('dataset/train/uovo')

print('Training set size:', len(train_empty)+len(train_egg))
print('Empty images:', len(train_empty))
print('Egg images:', len(train_egg))
# Out:
# Training set size: 1722
# Empty images: 867
# Egg images: 855

# %% [markdown]
# To simplify the data analysis stage, we build a dataframe which contains some useful information extracted from the path of the images.
#
# As a matter of fact, each image is characterized by the following attributes:
# - **path**: path where the image file is located.
# - **acquisition**: acquisition in which the image was collected.
# - **name**: name of the image.
# - **direction**: orientation of the image. The same image may be present in the dataset with different orientation. This was made to balanced the class of the data, since the egg images were less in number. A better explanation about direction can be found [here](https://www.kaggle.com/c/unina-data-mining-2021-minicontest-n3/data).
# - **label**: label of the image.

# %%
df_train = pd.DataFrame(columns=['path', 'acquisition', 'name', 'direction', 'label'])

# %%
label = 'empty'

for imm in train_empty:
  path = '/content/dataset/train/empty/' + imm

  if imm.startswith('Acquisizione'):
    acquisition, name1, name2, name3, direction = imm.split(sep='_')  
    name = name1 + '_' + name2 + '_' + name3
    direction = direction.split(sep='.')[0]

  row = {'path':[path], 'acquisition':[acquisition], 'name':[name], 'direction':[direction], 'label':[label]}
  df_train = df_train.append(pd.DataFrame(row))

# %%
label = 'egg'

for imm in train_egg:
  path = '/content/dataset/train/uovo/' + imm

  if imm.startswith('Acquisizione'):
    acquisition, name1, name2, name3, name4, direction = imm.split(sep='_')  
    name = name1 + '_' + name2 + '_' + name3  + '_' + name4
    direction = direction.split(sep='.')[0]

  if imm.startswith('KFM'):
    acquisition1, acquisition2, name1, name2, direction = imm.split(sep='_') 
    acquisition = acquisition1 + '_' + acquisition2
    name = name1 + '_' + name2
    direction = direction.split(sep='.')[0]

  if imm.startswith('Qualita'):
    acquisition, name1, name2, direction = imm.split(sep='_')  
    name = name1 + '_' + name2
    direction = direction.split(sep='.')[0]

  row = {'path':[path], 'acquisition':[acquisition], 'name':[name], 'direction':[direction], 'label':[label]}
  df_train = df_train.append(pd.DataFrame(row))

# %% [markdown]
# ### 1.2.2. Test set

# %%
test = os.listdir('dataset/test')

print('Test set size:', len(test))
# Out:
# Test set size: 738

# %% [markdown]
# # 2. Exploratory Data Analysis
# First of all, we want to gain a better knowledge of the data.

# %%
df_train.head()
# Out:
#                                                 path  ...  label
# 0  /content/dataset/train/empty/Acquisizione6_mic...  ...  empty
# 0  /content/dataset/train/empty/Acquisizione5_mic...  ...  empty
# 0  /content/dataset/train/empty/Acquisizione7_mic...  ...  empty
# 0  /content/dataset/train/empty/Acquisizione6_mic...  ...  empty
# 0  /content/dataset/train/empty/Acquisizione7_mic...  ...  empty
#
# [5 rows x 5 columns]

# %%
df_train.shape
# Out:
# (1722, 5)

# %%
df_train.describe(include='all')
# Out:
#                                                      path  ...  label
# count                                                1722  ...   1722
# unique                                               1722  ...      2
# top     /content/dataset/train/uovo/KFM_FLOTAC_FLOTAC ...  ...  empty
# freq                                                    1  ...    867
#
# [4 rows x 5 columns]

# %%
df_train.groupby('acquisition').path.count().plot.barh()
plt.show()

# %% [markdown]
# Different acquisitions have different size.

# %%
df_train.groupby('label').path.count().plot.barh()
plt.show()

# %% [markdown]
# Thanks to the "direction trick" the training set is balanced, in term of class.

# %%
df_train.groupby('direction').path.count().plot.barh()
plt.show()

# %%
df_train.groupby(['label', 'acquisition']).path.count().unstack(0).plot.barh()
plt.show()

# %% [markdown]
# In the figure above we can see the class distribution for different acquisition. We will use this information to split properly the training set in training, validation and test set.

# %%
df_train.groupby(['label', 'direction']).path.count().unstack(0).plot.barh()
plt.show()

# %% [markdown]
# The figure above confirms that different directions are used only for egg images.

# %%
df_train.groupby(['direction', 'acquisition']).path.count().unstack(0).plot.barh()
plt.show()

# %% [markdown]
# The figure above guarantees that different directions of the same image refer to the same acquisition.

# %% [markdown]
# # 3. Data Preparation
# Before moving forward we need to prepare our data so that a model can use it for both training and prediction.
#
# The basic idea is to apply a **stratified holdout** techinique, dividing the training set in 3 different datasets:
# - *training set* (60%), which will be used to train the model;
# - *validation set* (20%), which will be used to optimize the hyperparameters of the model;
# - *test set* (20%), which will be used to evaluate model's performance and to perform model selection.
#
# Stratification ensure that the class are balanced in all the subsets. Moreover, when splitting the dataset, we shold ensure that images from the same acquisition are not used for training and validation (or training and testing). In other words, training, validation and test set should be made up of different acquisitions to be as independent as possible.

# %% [markdown]
# ## 3.1. Hyperparameters tuning
# Now we prepare data for the hyperparameters optimization stage.

# %%
df_train_ = df_train.loc[(df_train.acquisition=='Acquisizione1') |
             (df_train.acquisition=='Acquisizione3') |
             (df_train.acquisition=='Acquisizione7')]
df_train_.shape
# Out:
# (1092, 5)

# %%
df_train_.groupby('label').path.count().plot.barh()
plt.show()

# %%
df_train_.groupby(['label', 'acquisition']).path.count().unstack(0).plot.barh()
plt.show()

# %%
df_val = df_train.loc[(df_train.acquisition=='Acquisizione5') |
             (df_train.acquisition=='Qualita2') |
             (df_train.acquisition=='KFM_FLOTAC')]
df_val.shape
# Out:
# (328, 5)

# %%
df_val.groupby('label').path.count().plot.barh()
plt.show()

# %%
df_val.groupby(['label', 'acquisition']).path.count().unstack(0).plot.barh()
plt.show()

# %%
print('Training set:', df_train_.shape[0]/df_train.shape[0])
print('Validation set:', df_val.shape[0]/df_train.shape[0])
# Out:
# Training set: 0.6341463414634146
# Validation set: 0.19047619047619047

# %%
# !mkdir /content/dataset/hyperparam

# !mkdir /content/dataset/hyperparam/train
# !mkdir /content/dataset/hyperparam/train/empty
# !mkdir /content/dataset/hyperparam/train/egg

# !mkdir /content/dataset/hyperparam/val
# !mkdir /content/dataset/hyperparam/val/empty
# !mkdir /content/dataset/hyperparam/val/egg

# %%
for index, row in df_train_.iterrows():
  if(row.label=='egg'):
    shutil.copy2(row.path, '/content/dataset/hyperparam/train/egg')
  if(row.label=='empty'):
    shutil.copy2(row.path, '/content/dataset/hyperparam/train/empty')

for index, row in df_val.iterrows():
  if(row.label=='egg'):
    shutil.copy2(row.path, '/content/dataset/hyperparam/val/egg')
  if(row.label=='empty'):
    shutil.copy2(row.path, '/content/dataset/hyperparam/val/empty')

# %% [markdown]
# ## 3.1. Model selection
# Now we prepare data for the model selection stage. We will use the union of training and validation set to train the model and test set to evaluate his performance.

# %%
df_train_val = df_train_.append(df_val)
df_train_val.shape
# Out:
# (1420, 5)

# %%
df_train_val.groupby('label').path.count().plot.barh()
plt.show()

# %%
df_train_val.groupby(['label', 'acquisition']).path.count().unstack(0).plot.barh()
plt.show()

# %%
df_test = df_train.loc[df_train.acquisition=='Acquisizione6']
df_test.shape
# Out:
# (302, 5)

# %%
df_test.groupby('label').path.count().plot.barh()
plt.show()

# %%
df_test.groupby(['label', 'acquisition']).path.count().unstack(0).plot.barh()
plt.savefig('/content/test_label_acquisition.png', bbox_inches='tight')
plt.show()

# %%
print('Training set:', df_train_val.shape[0]/df_train.shape[0])
print('Test set:', df_test.shape[0]/df_train.shape[0])
# Out:
# Training set: 0.8246225319396051
# Test set: 0.1753774680603949

# %%
# !mkdir /content/dataset/modelselect

# !mkdir /content/dataset/modelselect/train
# !mkdir /content/dataset/modelselect/train/empty
# !mkdir /content/dataset/modelselect/train/egg

# !mkdir /content/dataset/modelselect/test
# !mkdir /content/dataset/modelselect/test/empty
# !mkdir /content/dataset/modelselect/test/egg

# %%
for index, row in df_train_val.iterrows():
  if(row.label=='egg'):
    shutil.copy2(row.path, '/content/dataset/modelselect/train/egg')
  if(row.label=='empty'):
    shutil.copy2(row.path, '/content/dataset/modelselect/train/empty')

for index, row in df_test.iterrows():
  if(row.label=='egg'):
    shutil.copy2(row.path, '/content/dataset/modelselect/test/egg')
  if(row.label=='empty'):
    shutil.copy2(row.path, '/content/dataset/modelselect/test/empty')

# %% [markdown]
# # 4. Modelling
# Completed the previous stage, we can start seeking the best model for our classification problem.

# %%
# deterministic execution
torch.manual_seed(0)
# torch.set_deterministic(True)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True 

np.random.seed(0)

# %% [markdown]
# ## 4.1. Helper function
# Let's define some functions that will be used later in this section.

# %% [markdown]
# ### 4.1.1. Training and validation
# Function *train_val_model* is used to train the model on the training set and to evaluate his performance on an independent validation set. Basically it performs the following steps:
# - for each epoch
#   -  train phase
#     - set model in training mode
#     - for each batch
#       - reset the gradient
#       - forward (predition and loss)
#       - backward (optimization step)
#       - update loss and accuracy
#     - compute epoch loss and accuracy
#   - validation phase
#     - set model in validation mode
#     - for each batch
#       - reset the gradient
#       - forward (predition and loss)
#       - update loss and accuracy
#     - compute epoch loss and accuracy
#     - save the current best model

# %%
def train_val_model(model, dataloaders, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    train_loss = []
    train_acc = []
    val_loss = []
    val_acc = [] 

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_loss = 0.0
    best_epoch = -1   

    # for each epoch
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train() # set model in training mode
            else:
                model.eval()  # set model in validation mode

            running_loss = 0.0
            running_corrects = 0

            # for each batch
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad() # reset the gradient

                with torch.set_grad_enabled(phase == 'train'):
                    # forward
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    
                    if phase == 'train':
                        # backward
                        loss.backward()
                        optimizer.step()  # optimization step

                # update loss and accuracy
                running_loss += loss.item() * inputs.size(0) 
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train' and scheduler:
                scheduler.step()

            # compute epoch loss and accuracy
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                val_loss.append(epoch_loss)
                val_acc.append(epoch_acc)

            if phase == 'val' and ((epoch_acc > best_acc) or (epoch_acc == best_acc and epoch_loss < best_loss)):
                best_acc = epoch_acc
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                best_epoch = epoch

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    print('Best val Loss: {:4f}'.format(best_loss))
    print('Best epoch: {:d}'.format(best_epoch))

    # load best model weights
    model.load_state_dict(best_model_wts)

    return model, train_loss, train_acc, val_loss, val_acc

# %% [markdown]
# ### 4.1.2. Training
# Function *train_model* is used to train the model on the union of training and validation set. Basically it performs the same steps of the previous function, except for the validation phase which is not execute.

# %%
def train_model(model, dataloaders, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    train_loss = []
    train_acc = []

    # for each epoch
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        for phase in ['train']:
            if phase == 'train':
                model.train() # set model in training mode
            else:
                model.eval()  # set model in validation mode

            running_loss = 0.0
            running_corrects = 0

            # for each batch
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad() # reset the gradient

                with torch.set_grad_enabled(phase == 'train'):
                    # forward
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        # backward
                        loss.backward()
                        optimizer.step()  # optimization step

                # update loss and accuracy
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train' and scheduler:
                scheduler.step()

            # compute epoch loss and accuracy
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

    return model, train_loss, train_acc

# %% [markdown]
# ### 4.1.3. Utilities
# Function *set_parameter_requires_grad* is used to define the parameters of the network that has to be trained. It takes in input the model and a parameter *mode*, which may be:
# - *feature_extraction*: train only layers of the classifier (fully-connected layers);
# - *fine_tuning*: train all the layers of the network;
# - *mixed*: train the layers of the classifier and the last convolutional layer.

# %%
def set_parameter_requires_grad(model, mode, n=0, m=0):
    if mode == 'feature_extraction':
        print('Feature extraction: training classifier')
        for param in model.parameters():
            param.requires_grad = False
        for param in model.classifier.parameters():
            param.requires_grad = True
    elif mode == 'fine_tuning':
        print('Fine tuning: training all the layers')
        for param in model.parameters():
            param.requires_grad = True
    elif mode == 'mixed' and n!=0 and m!=0:
        print('Mixed: training classifier and last convolutional layer')
        for param in model.parameters():
            param.requires_grad = False
        for i in range(n, m+1):
            for param in model.features[i].parameters():
                param.requires_grad = True
        for param in model.classifier.parameters():
            param.requires_grad = True
    else:
        print("Invalid mode, exiting...")

# %% [markdown]
# Function *initialize_model* is used to initialize the network. It is possible to choose among *AlexNet*, *VGG11* and *GoogLeNet*. It takes in input the mode, used in the previous function, and a parameter *use_pretrained*, which specifies if the network should be pretrained or not.

# %%
def initialize_model(model_name, num_classes, mode, use_pretrained=True):
    model = None
    input_size = 0

    if model_name == "alexnet":
        """ Alexnet
        """
        model = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model, mode, n=10, m=12)
        num_ftrs = model.classifier[6].in_features
        model.classifier[6] = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "vgg11":
        """ VGG11_bn
        """
        model = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model, mode, n=25, m=28)
        num_ftrs = model.classifier[6].in_features
        model.classifier[6] = nn.Linear(num_ftrs, num_classes)
        input_size = 224
    
    elif model_name == "googlenet":
        """ GoogLeNet 
        """
        model = models.googlenet(pretrained=use_pretrained)
        set_parameter_requires_grad(model, mode)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    else:
        print("Invalid model name, exiting...")
        exit()

    return model, input_size

# %% [markdown]
# ## 4.2. Hyperparameters tuning
# The first step of the modelling stage is hyperparameters tuning, which is the process of choosing a set of optimal hyperparameters of a model. Given a certain model, we will train it on training data and evaluate his performance on validation data. We will repeat this procedure looking at model's performance and changing the hyperparameters accordingly. The whole process will be repeated for different models.
#
# For each model, we will consider the following hyperparameters:
# - *mode*: learning strategy (feature extraction, fine tuning or a "mixed" approach);
# - *batch_size*: size of a batch;
# - *num_epochs*: number of epochs to perform;
# - *loss function*: function to minimize during the training;
# - *optimizer*: optimization algorithm used to train the model;
#   - *learning_rate*: learning rate used by the optimization algorithm;
#   - *weight_decay*: L2 penalty;
#   - *learning rate scheduler*: scheduler used during the optimization algorithm, responsible for decreasing learning rate during the optimization;
#     - *gamma*: decay's factor.
#     - *step_size*: period of learning rate decay.

# %% [markdown]
# ### 4.2.1. AlexNet

# %% [markdown]
# Initialize the model, specifying the name and the number of classes of our problem.

# %%
model_name = 'alexnet'
num_classes = 2

mode = 'feature_extraction' # hyperparameter

model, input_size = initialize_model(model_name, num_classes, mode, use_pretrained=True)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))
# Feature extraction: training classifier
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# Define the hyperparameters.

# %%
print("Params to learn:")
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

batch_size = 32
num_epochs = 100

# loss function
criterion = nn.CrossEntropyLoss()

# optimizer
learning_rate = 0.00001
weight_decay = 0
optimizer = optim.Adam(params_to_update, lr=learning_rate, weight_decay=weight_decay)

# scheduler
gamma = 1
step_size = 10
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
# Out:
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias
# 	 classifier.4.weight
# 	 classifier.4.bias
# 	 classifier.6.weight
# 	 classifier.6.bias

# %% [markdown]
# Load training and validation data.

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.RandomRotation(90),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ]),
                   'val':transforms.Compose([transforms.Resize(224),
                                             transforms.ToTensor(),
                                             transforms.Normalize([0.485, 0.456, 0.406],
                                                                  [0.229, 0.224, 0.225])
                                             ])
                   }

data_dir = '/content/dataset/hyperparam'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1092, 'val': 328}
# ['egg', 'empty']

# %% [markdown]
# Set GPU as device, if available.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

model = model.to(device)
# Out:
# cuda:0

# %% [markdown]
# Train the model and evaluate his performans on validation set.

# %%
model, train_loss, train_acc, val_loss, val_acc = train_val_model(model, dataloaders, criterion, optimizer, scheduler, num_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.5985 Acc: 0.6767
# val Loss: 0.4660 Acc: 0.8994
#
# Epoch 1/99
# ----------
# train Loss: 0.4474 Acc: 0.8288
# val Loss: 0.3440 Acc: 0.9451
#
# Epoch 2/99
# ----------
# train Loss: 0.3643 Acc: 0.8581
# val Loss: 0.2671 Acc: 0.9451
#
# Epoch 3/99
# ----------
# train Loss: 0.3348 Acc: 0.8663
# val Loss: 0.2303 Acc: 0.9543
#
# Epoch 4/99
# ----------
# train Loss: 0.3033 Acc: 0.8855
# val Loss: 0.2045 Acc: 0.9543
#
# Epoch 5/99
# ----------
# train Loss: 0.2783 Acc: 0.8974
# val Loss: 0.1807 Acc: 0.9543
#
# Epoch 6/99
# ----------
# train Loss: 0.2593 Acc: 0.8892
# val Loss: 0.1787 Acc: 0.9451
#
# Epoch 7/99
# ----------
# train Loss: 0.2432 Acc: 0.8919
# val Loss: 0.1506 Acc: 0.9543
#
# Epoch 8/99
# ----------
# train Loss: 0.2469 Acc: 0.8984
# val Loss: 0.1498 Acc: 0.9543
#
# Epoch 9/99
# ----------
# train Loss: 0.2426 Acc: 0.9093
# val Loss: 0.1800 Acc: 0.9390
#
# Epoch 10/99
# ----------
# train Loss: 0.2207 Acc: 0.9167
# val Loss: 0.1507 Acc: 0.9512
#
# Epoch 11/99
# ----------
# train Loss: 0.2322 Acc: 0.9103
# val Loss: 0.1438 Acc: 0.9543
#
# Epoch 12/99
# ----------
# train Loss: 0.2235 Acc: 0.9093
# val Loss: 0.1304 Acc: 0.9543
#
# Epoch 13/99
# ----------
# train Loss: 0.2248 Acc: 0.9066
# val Loss: 0.1304 Acc: 0.9543
#
# Epoch 14/99
# ----------
# train Loss: 0.2154 Acc: 0.9158
# val Loss: 0.1410 Acc: 0.9451
#
# Epoch 15/99
# ----------
# train Loss: 0.2170 Acc: 0.9158
# val Loss: 0.1317 Acc: 0.9482
#
# Epoch 16/99
# ----------
# train Loss: 0.2052 Acc: 0.9194
# val Loss: 0.1441 Acc: 0.9360
#
# Epoch 17/99
# ----------
# train Loss: 0.2248 Acc: 0.9158
# val Loss: 0.1332 Acc: 0.9665
#
# Epoch 18/99
# ----------
# train Loss: 0.2097 Acc: 0.9148
# val Loss: 0.1315 Acc: 0.9634
#
# Epoch 19/99
# ----------
# train Loss: 0.2176 Acc: 0.9057
# val Loss: 0.1516 Acc: 0.9390
#
# Epoch 20/99
# train Loss: 0.1206 Acc: 0.9542
# val Loss: 0.2453 Acc: 0.9055
#
# Epoch 97/99
# ----------
# train Loss: 0.1273 Acc: 0.9515
# val Loss: 0.2680 Acc: 0.8963
#
# Epoch 98/99
# ----------
# train Loss: 0.1278 Acc: 0.9524
# val Loss: 0.2564 Acc: 0.9024
#
# Epoch 99/99
# ----------
# train Loss: 0.1111 Acc: 0.9560
# val Loss: 0.2368 Acc: 0.9085
#
# Training complete in 10m 46s
# Best val Acc: 0.987805
# Best val Loss: 0.125240
# Best epoch: 23

# %% [markdown]
# Use accuracy and loss plots to optimize the hyperparameters of the model.

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,4))

axs[0].plot(list(range(1,len(train_loss)+1)), train_loss, label='Training Loss')
axs[0].plot(list(range(1, len(val_loss)+1)), val_loss, label='Validation Loss')
axs[0].set_title('Training vs Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

axs[1].plot(list(range(1,len(train_acc)+1)), train_acc, label='Training Loss')
axs[1].plot(list(range(1, len(val_acc)+1)), val_acc, label='Validation Loss')
axs[1].set_title('Training vs Validation Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')

plt.show()

# %% [markdown]
# Save the best hyperparameters found for AlexNet.

# %%
model_name = 'alexnet'
num_classes = 2

alexnet_mode = 'feature_extraction'

alexnet, input_size = initialize_model(model_name, num_classes, alexnet_mode, use_pretrained=True)

alexnet_params = []
for name, param in alexnet.named_parameters():
    if param.requires_grad == True:
        alexnet_params.append(param)

alexnet_batch_size = 32
alexnet_num_epochs = 30

alexnet_criterion = nn.CrossEntropyLoss()

alexnet_learning_rate = 0.00001
alexnet_weight_decay = 0
alexnet_optimizer = optim.Adam(alexnet_params, lr=alexnet_learning_rate, weight_decay=alexnet_weight_decay)

alexnet_gamma = 1
alexnet_step_size = 10
alexnet_scheduler = lr_scheduler.StepLR(alexnet_optimizer, step_size=alexnet_step_size, gamma=alexnet_gamma)
# Out:
# Feature extraction: training classifier

# %% [markdown]
# ### 4.2.2. VGG11

# %%
model_name = 'vgg11'
num_classes = 2

mode = 'mixed' # hyperparameter

model, input_size = initialize_model(model_name, num_classes, mode, use_pretrained=True)
print(model)
# Out:
# Mixed: training classifier and last convolutional layer
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(inplace=True)
#     (28): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
print("Params to learn:")
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

batch_size = 32
num_epochs = 100

# loss function
criterion = nn.CrossEntropyLoss()

# optimizer
learning_rate = 0.00001
weight_decay = 0
optimizer = optim.Adam(params_to_update, lr=learning_rate, weight_decay=weight_decay)

# scheduler
gamma = 1
step_size = 10
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
# Out:
# Params to learn:
# 	 features.25.weight
# 	 features.25.bias
# 	 features.26.weight
# 	 features.26.bias
# 	 classifier.0.weight
# 	 classifier.0.bias
# 	 classifier.3.weight
# 	 classifier.3.bias
# 	 classifier.6.weight
# 	 classifier.6.bias

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ]),
                   'val':transforms.Compose([transforms.Resize(224),
                                             transforms.ToTensor(),
                                             transforms.Normalize([0.485, 0.456, 0.406],
                                                                  [0.229, 0.224, 0.225])
                                             ])
                   }

data_dir = '/content/dataset/hyperparam'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1092, 'val': 328}
# ['egg', 'empty']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

model = model.to(device)
# Out:
# cuda:0

# %%
model, train_loss, train_acc, val_loss, val_acc = train_val_model(model, dataloaders, criterion, optimizer, scheduler, num_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.5515 Acc: 0.7491
# val Loss: 0.2459 Acc: 0.9787
#
# Epoch 1/99
# ----------
# train Loss: 0.3251 Acc: 0.8919
# val Loss: 0.0960 Acc: 0.9726
#
# Epoch 2/99
# ----------
# train Loss: 0.2279 Acc: 0.9231
# val Loss: 0.0607 Acc: 0.9787
#
# Epoch 3/99
# ----------
# train Loss: 0.1686 Acc: 0.9451
# val Loss: 0.0579 Acc: 0.9726
#
# Epoch 4/99
# ----------
# train Loss: 0.1259 Acc: 0.9606
# val Loss: 0.0352 Acc: 0.9848
#
# Epoch 5/99
# ----------
# train Loss: 0.1005 Acc: 0.9734
# val Loss: 0.0429 Acc: 0.9787
#
# Epoch 6/99
# ----------
# train Loss: 0.0772 Acc: 0.9799
# val Loss: 0.0269 Acc: 0.9878
#
# Epoch 7/99
# ----------
# train Loss: 0.0613 Acc: 0.9799
# val Loss: 0.0237 Acc: 0.9878
#
# Epoch 8/99
# ----------
# train Loss: 0.0573 Acc: 0.9844
# val Loss: 0.0215 Acc: 0.9878
#
# Epoch 9/99
# ----------
# train Loss: 0.0397 Acc: 0.9890
# val Loss: 0.0121 Acc: 1.0000
#
# Epoch 10/99
# ----------
# train Loss: 0.0326 Acc: 0.9954
# val Loss: 0.0151 Acc: 0.9970
#
# Epoch 11/99
# ----------
# train Loss: 0.0281 Acc: 0.9927
# val Loss: 0.0122 Acc: 1.0000
#
# Epoch 12/99
# ----------
# train Loss: 0.0229 Acc: 0.9973
# val Loss: 0.0131 Acc: 1.0000
#
# Epoch 13/99
# ----------
# train Loss: 0.0214 Acc: 0.9945
# val Loss: 0.0088 Acc: 1.0000
#
# Epoch 14/99
# ----------
# train Loss: 0.0201 Acc: 0.9973
# val Loss: 0.0117 Acc: 1.0000
#
# Epoch 15/99
# ----------
# train Loss: 0.0136 Acc: 0.9982
# val Loss: 0.0183 Acc: 0.9970
#
# Epoch 16/99
# ----------
# train Loss: 0.0164 Acc: 0.9973
# val Loss: 0.0069 Acc: 1.0000
#
# Epoch 17/99
# ----------
# train Loss: 0.0124 Acc: 0.9982
# val Loss: 0.0105 Acc: 1.0000
#
# Epoch 18/99
# ----------
# train Loss: 0.0110 Acc: 1.0000
# val Loss: 0.0061 Acc: 1.0000
#
# Epoch 19/99
# ----------
# train Loss: 0.0119 Acc: 0.9982
# val Loss: 0.0057 Acc: 1.0000
#
# Epoch 20/99
# ----------
# train Loss: 0.0072 Acc: 0.9991
# val Loss: 0.0052 Acc: 1.0000
#
# Epoch 21/99
# ----------
# train Loss: 0.0085 Acc: 1.0000
# val Loss: 0.0055 Acc: 1.0000
#
# Epoch 22/99
# ----------
# train Loss: 0.0106 Acc: 1.0000
# val Loss: 0.0099 Acc: 1.0000
#
# Epoch 23/99
# ----------
# train Loss: 0.0050 Acc: 0.9991
# val Loss: 0.0052 Acc: 1.0000
#
# Epoch 24/99
# ----------
# train Loss: 0.0052 Acc: 1.0000
# val Loss: 0.0065 Acc: 1.0000
#
# Epoch 25/99
# ----------
# train Loss: 0.0060 Acc: 0.9991
# val Loss: 0.0054 Acc: 1.0000
#
# Epoch 26/99
# ----------
# train Loss: 0.0028 Acc: 1.0000
# val Loss: 0.0119 Acc: 0.9970
#
# Epoch 27/99
# ----------
# train Loss: 0.0065 Acc: 0.9991
# val Loss: 0.0089 Acc: 0.9970
#
# Epoch 28/99
# ----------
# train Loss: 0.0058 Acc: 1.0000
# val Loss: 0.0101 Acc: 0.9970
#
# Epoch 29/99
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.0075 Acc: 0.9970
#
# Epoch 30/99
# ----------
# train Loss: 0.0043 Acc: 1.0000
# val Loss: 0.0111 Acc: 0.9970
#
# Epoch 31/99
# ----------
# train Loss: 0.0047 Acc: 0.9991
# val Loss: 0.0072 Acc: 0.9970
#
# Epoch 32/99
# ----------
# train Loss: 0.0027 Acc: 1.0000
# val Loss: 0.0082 Acc: 0.9970
#
# Epoch 33/99
# ----------
# train Loss: 0.0020 Acc: 1.0000
# val Loss: 0.0118 Acc: 0.9970
#
# Epoch 34/99
# ----------
# train Loss: 0.0023 Acc: 1.0000
# val Loss: 0.0074 Acc: 0.9970
#
# Epoch 35/99
# ----------
# train Loss: 0.0041 Acc: 0.9991
# val Loss: 0.0093 Acc: 0.9970
#
# Epoch 36/99
# ----------
# train Loss: 0.0019 Acc: 1.0000
# val Loss: 0.0058 Acc: 0.9970
#
# Epoch 37/99
# ----------
# train Loss: 0.0064 Acc: 0.9973
# val Loss: 0.0059 Acc: 0.9970
#
# Epoch 38/99
# ----------
# train Loss: 0.0023 Acc: 1.0000
# val Loss: 0.0207 Acc: 0.9909
#
# Epoch 39/99
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0115 Acc: 0.9970
#
# Epoch 40/99
# ----------
# train Loss: 0.0035 Acc: 0.9991
# val Loss: 0.0204 Acc: 0.9939
#
# Epoch 41/99
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0054 Acc: 0.9970
#
# Epoch 42/99
# ----------
# train Loss: 0.0017 Acc: 1.0000
# val Loss: 0.0109 Acc: 0.9970
#
# Epoch 43/99
# ----------
# train Loss: 0.0039 Acc: 0.9991
# val Loss: 0.0050 Acc: 0.9970
#
# Epoch 44/99
# ----------
# train Loss: 0.0021 Acc: 1.0000
# val Loss: 0.0057 Acc: 0.9970
#
# Epoch 45/99
# ----------
# train Loss: 0.0017 Acc: 1.0000
# val Loss: 0.0054 Acc: 0.9970
#
# Epoch 46/99
# ----------
# train Loss: 0.0014 Acc: 1.0000
# val Loss: 0.0081 Acc: 0.9970
#
# Epoch 47/99
# ----------
# train Loss: 0.0059 Acc: 0.9982
# val Loss: 0.0152 Acc: 0.9970
#
# Epoch 48/99
# ----------
# train Loss: 0.0090 Acc: 0.9973
# val Loss: 0.0012 Acc: 1.0000
#
# Epoch 49/99
# ----------
# train Loss: 0.0033 Acc: 0.9991
# val Loss: 0.0174 Acc: 0.9909
#
# Epoch 50/99
# ----------
# train Loss: 0.0015 Acc: 1.0000
# val Loss: 0.0108 Acc: 0.9939
#
# Epoch 51/99
# ----------
# train Loss: 0.0016 Acc: 0.9991
# val Loss: 0.0022 Acc: 1.0000
#
# Epoch 52/99
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0063 Acc: 0.9970
#
# Epoch 53/99
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0058 Acc: 0.9970
#
# Epoch 54/99
# ----------
# train Loss: 0.0043 Acc: 0.9991
# val Loss: 0.0204 Acc: 0.9909
#
# Epoch 55/99
# ----------
# train Loss: 0.0049 Acc: 0.9991
# val Loss: 0.0203 Acc: 0.9909
#
# Epoch 56/99
# ----------
# train Loss: 0.0015 Acc: 0.9991
# val Loss: 0.0087 Acc: 0.9970
#
# Epoch 57/99
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0143 Acc: 0.9970
#
# Epoch 58/99
# ----------
# train Loss: 0.0042 Acc: 0.9991
# val Loss: 0.0153 Acc: 0.9970
#
# Epoch 59/99
# ----------
# train Loss: 0.0035 Acc: 0.9991
# val Loss: 0.0314 Acc: 0.9878
#
# Epoch 60/99
# ----------
# train Loss: 0.0011 Acc: 1.0000
# val Loss: 0.0359 Acc: 0.9878
#
# Epoch 61/99
# ----------
# train Loss: 0.0018 Acc: 1.0000
# val Loss: 0.0722 Acc: 0.9695
#
# Epoch 62/99
# ----------
# train Loss: 0.0009 Acc: 1.0000
# val Loss: 0.0379 Acc: 0.9878
#
# Epoch 63/99
# ----------
# train Loss: 0.0012 Acc: 1.0000
# val Loss: 0.0246 Acc: 0.9909
#
# Epoch 64/99
# ----------
# train Loss: 0.0015 Acc: 0.9991
# val Loss: 0.0143 Acc: 0.9970
#
# Epoch 65/99
# ----------
# train Loss: 0.0025 Acc: 0.9991
# val Loss: 0.0212 Acc: 0.9970
#
# Epoch 66/99
# ----------
# train Loss: 0.0047 Acc: 0.9982
# val Loss: 0.0151 Acc: 0.9970
#
# Epoch 67/99
# ----------
# train Loss: 0.0046 Acc: 0.9982
# val Loss: 0.0060 Acc: 0.9970
#
# Epoch 68/99
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0052 Acc: 0.9970
#
# Epoch 69/99
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0066 Acc: 0.9970
#
# Epoch 70/99
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0037 Acc: 0.9970
#
# Epoch 71/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0063 Acc: 0.9970
#
# Epoch 72/99
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0063 Acc: 0.9970
#
# Epoch 73/99
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0038 Acc: 0.9970
#
# Epoch 74/99
# ----------
# train Loss: 0.0008 Acc: 1.0000
# val Loss: 0.0078 Acc: 0.9970
#
# Epoch 75/99
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0097 Acc: 0.9970
#
# Epoch 76/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0065 Acc: 0.9970
#
# Epoch 77/99
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0078 Acc: 0.9970
#
# Epoch 78/99
# ----------
# train Loss: 0.0010 Acc: 1.0000
# val Loss: 0.0065 Acc: 0.9970
#
# Epoch 79/99
# ----------
# train Loss: 0.0006 Acc: 1.0000
# val Loss: 0.0048 Acc: 0.9970
#
# Epoch 80/99
# ----------
# train Loss: 0.0013 Acc: 0.9991
# val Loss: 0.0064 Acc: 0.9970
#
# Epoch 81/99
# ----------
# train Loss: 0.0007 Acc: 1.0000
# val Loss: 0.0072 Acc: 0.9970
#
# Epoch 82/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0048 Acc: 0.9970
#
# Epoch 83/99
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0028 Acc: 0.9970
#
# Epoch 84/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0060 Acc: 0.9970
#
# Epoch 85/99
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0063 Acc: 0.9970
#
# Epoch 86/99
# ----------
# train Loss: 0.0015 Acc: 0.9991
# val Loss: 0.0075 Acc: 0.9970
#
# Epoch 87/99
# ----------
# train Loss: 0.0014 Acc: 1.0000
# val Loss: 0.0192 Acc: 0.9970
#
# Epoch 88/99
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0100 Acc: 0.9970
#
# Epoch 89/99
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0077 Acc: 0.9970
#
# Epoch 90/99
# ----------
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.0057 Acc: 0.9970
#
# Epoch 91/99
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0058 Acc: 0.9970
#
# Epoch 92/99
# ----------
# train Loss: 0.0028 Acc: 0.9991
# val Loss: 0.0040 Acc: 0.9970
#
# Epoch 93/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0097 Acc: 0.9970
#
# Epoch 94/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0051 Acc: 0.9970
#
# Epoch 95/99
# ----------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0038 Acc: 0.9970
#
# Epoch 96/99
# ----------
# train Loss: 0.0005 Acc: 1.0000
# val Loss: 0.0098 Acc: 0.9970
#
# Epoch 97/99
# ----------
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.0075 Acc: 0.9970
#
# Epoch 98/99
# ----------
# train Loss: 0.0020 Acc: 0.9991
# val Loss: 0.0073 Acc: 0.9970
#
# Epoch 99/99
# ----------
# train Loss: 0.0203 Acc: 0.9954
# val Loss: 0.0042 Acc: 0.9970
#
# Training complete in 16m 19s
# Best val Acc: 1.000000
# Best val Loss: 0.001249
# Best epoch: 48

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,4))

axs[0].plot(list(range(1,len(train_loss)+1)), train_loss, label='Training Loss')
axs[0].plot(list(range(1, len(val_loss)+1)), val_loss, label='Validation Loss')
axs[0].set_title('Training vs Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(list(range(1,len(train_acc)+1)), train_acc, label='Training Loss')
axs[1].plot(list(range(1, len(val_acc)+1)), val_acc, label='Validation Loss')
axs[1].set_title('Training vs Validation Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

plt.show()

# %%
model_name = 'vgg11'
num_classes = 2

vgg11_mode = 'mixed'

vgg11, input_size = initialize_model(model_name, num_classes, vgg11_mode, use_pretrained=True)

vgg11_params = []
for name, param in vgg11.named_parameters():
    if param.requires_grad == True:
        vgg11_params.append(param)

vgg11_batch_size = 32
vgg11_num_epochs = 30

vgg11_criterion = nn.CrossEntropyLoss()

vgg11_learning_rate = 0.00001
vgg11_weight_decay = 0
vgg11_optimizer = optim.Adam(vgg11_params, lr=vgg11_learning_rate, weight_decay=vgg11_weight_decay)

vgg11_gamma = 1
vgg11_step_size = 10
vgg11_scheduler = lr_scheduler.StepLR(vgg11_optimizer, step_size=vgg11_step_size, gamma=vgg11_gamma)
# Out:
# Mixed: training classifier and last convolutional layer

# %% [markdown]
# ### 4.2.3. GoogLeNet

# %%
model_name = 'googlenet'
num_classes = 2

mode = 'fine_tuning' # hyperparameter

model, input_size = initialize_model(model_name, num_classes, mode, use_pretrained=True)
print(model)
# Out:
# Fine tuning: training all the layers
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=2, bias=True)
# )

# %%
print("Params to learn:")
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)

batch_size = 32
num_epochs = 100

# loss function
criterion = nn.CrossEntropyLoss()

# optimizer
learning_rate = 0.00001
weight_decay = 0
optimizer = optim.Adam(params_to_update, lr=learning_rate, weight_decay=weight_decay)

# scheduler
gamma = 1
step_size = 10
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
# Out:
# Params to learn:
# 	 conv1.conv.weight
# 	 conv1.bn.weight
# 	 conv1.bn.bias
# 	 conv2.conv.weight
# 	 conv2.bn.weight
# 	 conv2.bn.bias
# 	 conv3.conv.weight
# 	 conv3.bn.weight
# 	 conv3.bn.bias
# 	 inception3a.branch1.conv.weight
# 	 inception3a.branch1.bn.weight
# 	 inception3a.branch1.bn.bias
# 	 inception3a.branch2.0.conv.weight
# 	 inception3a.branch2.0.bn.weight
# 	 inception3a.branch2.0.bn.bias
# 	 inception3a.branch2.1.conv.weight
# 	 inception3a.branch2.1.bn.weight
# 	 inception3a.branch2.1.bn.bias
# 	 inception3a.branch3.0.conv.weight
# 	 inception3a.branch3.0.bn.weight
# 	 inception3a.branch3.0.bn.bias
# 	 inception3a.branch3.1.conv.weight
# 	 inception3a.branch3.1.bn.weight
# 	 inception3a.branch3.1.bn.bias
# 	 inception3a.branch4.1.conv.weight
# 	 inception3a.branch4.1.bn.weight
# 	 inception3a.branch4.1.bn.bias
# 	 inception4d.branch2.0.conv.weight
# 	 inception4d.branch2.0.bn.weight
# 	 inception4d.branch2.0.bn.bias
# 	 inception4d.branch2.1.conv.weight
# 	 inception4d.branch2.1.bn.weight
# 	 inception4d.branch2.1.bn.bias
# 	 inception4d.branch3.0.conv.weight
# 	 inception4d.branch3.0.bn.weight
# 	 inception4d.branch3.0.bn.bias
# 	 inception4d.branch3.1.conv.weight
# 	 inception4d.branch3.1.bn.weight
# 	 inception4d.branch3.1.bn.bias
# 	 inception4d.branch4.1.conv.weight
# 	 inception4d.branch4.1.bn.weight
# 	 inception4d.branch4.1.bn.bias
# 	 inception4e.branch1.conv.weight
# 	 inception4e.branch1.bn.weight
# 	 inception4e.branch1.bn.bias
# 	 inception4e.branch2.0.conv.weight
# 	 inception4e.branch2.0.bn.weight
# 	 inception4e.branch2.0.bn.bias
# 	 inception4e.branch2.1.conv.weight
# 	 inception4e.branch2.1.bn.weight
# 	 inception4e.branch2.1.bn.bias
# 	 inception4e.branch3.0.conv.weight
# 	 inception4e.branch3.0.bn.weight
# 	 inception4e.branch3.0.bn.bias
# 	 inception4e.branch3.1.conv.weight
# 	 inception4e.branch3.1.bn.weight
# 	 inception4e.branch3.1.bn.bias
# 	 inception4e.branch4.1.conv.weight
# 	 inception4e.branch4.1.bn.weight
# 	 inception4e.branch4.1.bn.bias
# 	 inception5a.branch1.conv.weight
# 	 inception5a.branch1.bn.weight
# 	 inception5a.branch1.bn.bias
# 	 inception5a.branch2.0.conv.weight
# 	 inception5a.branch2.0.bn.weight
# 	 inception5a.branch2.0.bn.bias
# 	 inception5a.branch2.1.conv.weight
# 	 inception5a.branch2.1.bn.weight
# 	 inception5a.branch2.1.bn.bias
# 	 inception5a.branch3.0.conv.weight
# 	 inception5a.branch3.0.bn.weight
# 	 inception5a.branch3.0.bn.bias
# 	 inception5a.branch3.1.conv.weight
# 	 inception5a.branch3.1.bn.weight
# 	 inception5a.branch3.1.bn.bias
# 	 inception5a.branch4.1.conv.weight
# 	 inception5a.branch4.1.bn.weight
# 	 inception5a.branch4.1.bn.bias
# 	 inception5b.branch1.conv.weight
# 	 inception5b.branch1.bn.weight
# 	 inception5b.branch1.bn.bias
# 	 inception5b.branch2.0.conv.weight
# 	 inception5b.branch2.0.bn.weight
# 	 inception5b.branch2.0.bn.bias
# 	 inception5b.branch2.1.conv.weight
# 	 inception5b.branch2.1.bn.weight
# 	 inception5b.branch2.1.bn.bias
# 	 inception5b.branch3.0.conv.weight
# 	 inception5b.branch3.0.bn.weight
# 	 inception5b.branch3.0.bn.bias
# 	 inception5b.branch3.1.conv.weight
# 	 inception5b.branch3.1.bn.weight
# 	 inception5b.branch3.1.bn.bias
# 	 inception5b.branch4.1.conv.weight
# 	 inception5b.branch4.1.bn.weight
# 	 inception5b.branch4.1.bn.bias
# 	 fc.weight
# 	 fc.bias

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ]),
                   'val':transforms.Compose([transforms.Resize(224),
                                             transforms.ToTensor(),
                                             transforms.Normalize([0.485, 0.456, 0.406],
                                                                  [0.229, 0.224, 0.225])
                                             ])
                   }

data_dir = '/content/dataset/hyperparam'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1092, 'val': 328}
# ['egg', 'empty']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

model = model.to(device)
# Out:
# cuda:0

# %%
model, train_loss, train_acc, val_loss, val_acc = train_val_model(model, dataloaders, criterion, optimizer, scheduler, num_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.6279 Acc: 0.6209
# val Loss: 0.4931 Acc: 0.8537
#
# Epoch 1/99
# ----------
# train Loss: 0.4791 Acc: 0.8159
# val Loss: 0.3389 Acc: 0.9787
#
# Epoch 2/99
# ----------
# train Loss: 0.3661 Acc: 0.8929
# val Loss: 0.2227 Acc: 0.9878
#
# Epoch 3/99
# ----------
# train Loss: 0.3009 Acc: 0.9093
# val Loss: 0.1681 Acc: 0.9878
#
# Epoch 4/99
# ----------
# train Loss: 0.2500 Acc: 0.9267
# val Loss: 0.1352 Acc: 0.9878
#
# Epoch 5/99
# ----------
# train Loss: 0.1994 Acc: 0.9560
# val Loss: 0.1091 Acc: 0.9878
#
# Epoch 6/99
# ----------
# train Loss: 0.1719 Acc: 0.9625
# val Loss: 0.0928 Acc: 0.9878
#
# Epoch 7/99
# ----------
# train Loss: 0.1494 Acc: 0.9661
# val Loss: 0.0919 Acc: 0.9878
#
# Epoch 8/99
# ----------
# train Loss: 0.1351 Acc: 0.9679
# val Loss: 0.0862 Acc: 0.9878
#
# Epoch 9/99
# ----------
# train Loss: 0.1022 Acc: 0.9817
# val Loss: 0.0776 Acc: 0.9878
#
# Epoch 10/99
# ----------
# train Loss: 0.0970 Acc: 0.9881
# val Loss: 0.0731 Acc: 0.9878
#
# Epoch 11/99
# ----------
# train Loss: 0.0799 Acc: 0.9853
# val Loss: 0.0627 Acc: 0.9939
#
# Epoch 12/99
# ----------
# train Loss: 0.0676 Acc: 0.9927
# val Loss: 0.0598 Acc: 0.9939
#
# Epoch 13/99
# ----------
# train Loss: 0.0774 Acc: 0.9817
# val Loss: 0.0775 Acc: 0.9878
#
# Epoch 14/99
# ----------
# train Loss: 0.0536 Acc: 0.9982
# val Loss: 0.0678 Acc: 0.9939
#
# Epoch 15/99
# ----------
# train Loss: 0.0521 Acc: 0.9945
# val Loss: 0.0619 Acc: 0.9939
#
# Epoch 16/99
# ----------
# train Loss: 0.0483 Acc: 0.9945
# val Loss: 0.0548 Acc: 0.9939
#
# Epoch 17/99
# ----------
# train Loss: 0.0378 Acc: 0.9982
# val Loss: 0.0519 Acc: 0.9970
#
# Epoch 18/99
# ----------
# train Loss: 0.0411 Acc: 0.9927
# val Loss: 0.0656 Acc: 0.9817
#
# Epoch 19/99
# ----------
# train Loss: 0.0402 Acc: 0.9954
# val Loss: 0.0604 Acc: 0.9848
#
# Epoch 20/99
# ----------
# train Loss: 0.0337 Acc: 0.9945
# val Loss: 0.0518 Acc: 0.9909
#
# Epoch 21/99
# ----------
# train Loss: 0.0355 Acc: 0.9954
# val Loss: 0.0606 Acc: 0.9878
# %%
fig, axs = plt.subplots(1, 2, figsize=(10,4))

axs[0].plot(list(range(1,len(train_loss)+1)), train_loss, label='Training Loss')
axs[0].plot(list(range(1, len(val_loss)+1)), val_loss, label='Validation Loss')
axs[0].set_title('Training vs Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

axs[1].plot(list(range(1,len(train_acc)+1)), train_acc, label='Training Loss')
axs[1].plot(list(range(1, len(val_acc)+1)), val_acc, label='Validation Loss')
axs[1].set_title('Training vs Validation Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

plt.show()

# %%
model_name = 'googlenet'
num_classes = 2

googlenet_mode = 'fine_tuning'

googlenet, input_size = initialize_model(model_name, num_classes, googlenet_mode, use_pretrained=True)

googlenet_params = []
for name, param in googlenet.named_parameters():
    if param.requires_grad == True:
        googlenet_params.append(param)

googlenet_batch_size = 32
googlenet_num_epochs = 30

googlenet_criterion = nn.CrossEntropyLoss()

googlenet_learning_rate = 0.00001
googlenet_weight_decay = 0
googlenet_optimizer = optim.Adam(googlenet_params, lr=googlenet_learning_rate, weight_decay=googlenet_weight_decay)

googlenet_gamma = 1
googlenet_step_size = 10
googlenet_scheduler = lr_scheduler.StepLR(googlenet_optimizer, step_size=googlenet_step_size, gamma=googlenet_gamma)
# Out:
# Fine tuning: training all the layers

# %% [markdown]
# ## 4.3. Model selection
# Once found the best hyperparameters for each model, we can compare their performance on an independent test set. To this end, we train each model on the union of training and validation data, with the hyperparameters found in the previous stage, and evaluate his performance on the test data. The model that gains the best performance on the test set will be choose for the submission.

# %% [markdown]
# ### 4.3.1. AlexNet

# %%
model_name = 'alexnet'
num_classes = 2

alexnet_mode = 'feature_extraction'

alexnet, input_size = initialize_model(model_name, num_classes, alexnet_mode, use_pretrained=True)

alexnet_params = []
for name, param in alexnet.named_parameters():
    if param.requires_grad == True:
        alexnet_params.append(param)

alexnet_batch_size = 32
alexnet_num_epochs = 30

alexnet_criterion = nn.CrossEntropyLoss()

alexnet_learning_rate = 0.00001
alexnet_weight_decay = 0
alexnet_optimizer = optim.Adam(alexnet_params, lr=alexnet_learning_rate, weight_decay=alexnet_weight_decay)

alexnet_gamma = 1
alexnet_step_size = 10
alexnet_scheduler = lr_scheduler.StepLR(alexnet_optimizer, step_size=alexnet_step_size, gamma=alexnet_gamma)
# Out:
# Feature extraction: training classifier

# %%
print(alexnet)
print()
print("Params to learn:")
for name, param in alexnet.named_parameters():
    if param.requires_grad == True:
        print("\t",name)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias
# 	 classifier.4.weight
# 	 classifier.4.bias
# 	 classifier.6.weight
# 	 classifier.6.bias

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.RandomRotation(90),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ])
                   }

data_dir = '/content/dataset/modelselect'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=alexnet_batch_size, shuffle=True, num_workers=4) for x in ['train']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1420}
# ['egg', 'empty']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

alexnet = alexnet.to(device)
# Out:
# cuda:0

# %% [markdown]
# Train the model with the best hyperparameters on the union of training and validation set.

# %%
alexnet, train_loss, train_acc = train_model(alexnet, dataloaders, alexnet_criterion, alexnet_optimizer, alexnet_scheduler, alexnet_num_epochs)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.5146 Acc: 0.7697
#
# Epoch 1/29
# ----------
# train Loss: 0.3578 Acc: 0.8592
#
# Epoch 2/29
# ----------
# train Loss: 0.2970 Acc: 0.8937
#
# Epoch 3/29
# ----------
# train Loss: 0.2706 Acc: 0.8923
#
# Epoch 4/29
# ----------
# train Loss: 0.2484 Acc: 0.9021
#
# Epoch 5/29
# ----------
# train Loss: 0.2369 Acc: 0.9077
#
# Epoch 6/29
# ----------
# train Loss: 0.2372 Acc: 0.9070
#
# Epoch 7/29
# ----------
# train Loss: 0.2121 Acc: 0.9218
#
# Epoch 8/29
# ----------
# train Loss: 0.2129 Acc: 0.9176
#
# Epoch 9/29
# ----------
# train Loss: 0.2146 Acc: 0.9127
#
# Epoch 10/29
# ----------
# train Loss: 0.1945 Acc: 0.9218
#
# Epoch 11/29
# ----------
# train Loss: 0.2078 Acc: 0.9204
#
# Epoch 12/29
# ----------
# train Loss: 0.1941 Acc: 0.9155
#
# Epoch 13/29
# ----------
# train Loss: 0.1919 Acc: 0.9218
#
# Epoch 14/29
# ----------
# train Loss: 0.1770 Acc: 0.9387
#
# Epoch 15/29
# ----------
# train Loss: 0.1780 Acc: 0.9324
#
# Epoch 16/29
# ----------
# train Loss: 0.1764 Acc: 0.9324
#
# Epoch 17/29
# ----------
# train Loss: 0.1750 Acc: 0.9268
#
# Epoch 18/29
# ----------
# train Loss: 0.1723 Acc: 0.9345
#
# Epoch 19/29
# ----------
# train Loss: 0.1828 Acc: 0.9303
#
# Epoch 20/29
# ----------
# train Loss: 0.1748 Acc: 0.9317
#
# Epoch 21/29
# ----------
# train Loss: 0.1641 Acc: 0.9437
#
# Epoch 22/29
# ----------
# train Loss: 0.1622 Acc: 0.9359
#
# Epoch 23/29
# ----------
# train Loss: 0.1638 Acc: 0.9366
#
# Epoch 24/29
# ----------
# train Loss: 0.1460 Acc: 0.9493
#
# Epoch 25/29
# ----------
# train Loss: 0.1545 Acc: 0.9359
#
# Epoch 26/29
# ----------
# train Loss: 0.1593 Acc: 0.9324
#
# Epoch 27/29
# ----------
# train Loss: 0.1560 Acc: 0.9394
#
# Epoch 28/29
# ----------
# train Loss: 0.1484 Acc: 0.9394
#
# Epoch 29/29
# ----------
# train Loss: 0.1605 Acc: 0.9338
#
# Training complete in 2m 24s

# %% [markdown]
# Predict the class of the test's images.

# %%
alexnet.eval()

df_res = pd.DataFrame(columns=['path', 'acquisition', 'name', 'direction', 'label', 'predicted'])

data_transforms = transforms.Compose([transforms.Resize(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])
                                      ])

for index, row in df_test.iterrows():
  input = row.path
  print('Working on '+ input)

  img = Image.open(input)
  img = data_transforms(img).to(device)
  img = img.unsqueeze_(0)
  outputs = alexnet(img)
  _, predicted = torch.max(outputs, 1)

  res = row.copy()
  res['predicted'] = class_names[predicted.item()]

  df_res = df_res.append(res)
# Out:
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_09_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_BDX.png

# %% [markdown]
# Evaluate model's performance on test set.

# %%
true_label = df_res.label.values
predicted = df_res.predicted.values

print((np.sum((true_label == predicted).astype(int)))/df_res.shape[0])
# Out:
# 0.7913907284768212

# %%
confusion_matrix(true_label, predicted)
# Out:
# array([[ 88,  52],
#        [ 11, 151]])

# %% [markdown]
# ### 4.3.2. VGG11

# %%
model_name = 'vgg11'
num_classes = 2

vgg11_mode = 'mixed'

vgg11, input_size = initialize_model(model_name, num_classes, vgg11_mode, use_pretrained=True)

vgg11_params = []
for name, param in vgg11.named_parameters():
    if param.requires_grad == True:
        vgg11_params.append(param)

vgg11_batch_size = 32
vgg11_num_epochs = 30

vgg11_criterion = nn.CrossEntropyLoss()

vgg11_learning_rate = 0.00001
vgg11_weight_decay = 0
vgg11_optimizer = optim.Adam(vgg11_params, lr=vgg11_learning_rate, weight_decay=vgg11_weight_decay)

vgg11_gamma = 1
vgg11_step_size = 10
vgg11_scheduler = lr_scheduler.StepLR(vgg11_optimizer, step_size=vgg11_step_size, gamma=vgg11_gamma)
# Out:
# Mixed: training classifier and last convolutional layer

# %%
print(vgg11)
print()
print("Params to learn:")
for name, param in vgg11.named_parameters():
    if param.requires_grad == True:
        print("\t",name)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(inplace=True)
#     (28): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# Params to learn:
# 	 features.25.weight
# 	 features.25.bias
# 	 features.26.weight
# 	 features.26.bias
# 	 classifier.0.weight
# 	 classifier.0.bias
# 	 classifier.3.weight
# 	 classifier.3.bias
# 	 classifier.6.weight
# 	 classifier.6.bias

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ])
                   }

data_dir = '/content/dataset/modelselect'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=vgg11_batch_size, shuffle=True, num_workers=4) for x in ['train']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1420}
# ['egg', 'empty']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

vgg11 = vgg11.to(device)
# Out:
# cuda:0

# %%
vgg11, train_loss, train_acc = train_model(vgg11, dataloaders, vgg11_criterion, vgg11_optimizer, vgg11_scheduler, vgg11_num_epochs)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.4917 Acc: 0.7972
#
# Epoch 1/29
# ----------
# train Loss: 0.2619 Acc: 0.9021
#
# Epoch 2/29
# ----------
# train Loss: 0.1772 Acc: 0.9366
#
# Epoch 3/29
# ----------
# train Loss: 0.1366 Acc: 0.9514
#
# Epoch 4/29
# ----------
# train Loss: 0.0994 Acc: 0.9613
#
# Epoch 5/29
# ----------
# train Loss: 0.0762 Acc: 0.9761
#
# Epoch 6/29
# ----------
# train Loss: 0.0590 Acc: 0.9852
#
# Epoch 7/29
# ----------
# train Loss: 0.0386 Acc: 0.9923
#
# Epoch 8/29
# ----------
# train Loss: 0.0347 Acc: 0.9908
#
# Epoch 9/29
# ----------
# train Loss: 0.0245 Acc: 0.9965
#
# Epoch 10/29
# ----------
# train Loss: 0.0210 Acc: 0.9951
#
# Epoch 11/29
# ----------
# train Loss: 0.0193 Acc: 0.9965
#
# Epoch 12/29
# ----------
# train Loss: 0.0171 Acc: 0.9951
#
# Epoch 13/29
# ----------
# train Loss: 0.0107 Acc: 0.9986
#
# Epoch 14/29
# ----------
# train Loss: 0.0135 Acc: 0.9972
#
# Epoch 15/29
# ----------
# train Loss: 0.0080 Acc: 0.9986
#
# Epoch 16/29
# ----------
# train Loss: 0.0076 Acc: 0.9993
#
# Epoch 17/29
# ----------
# train Loss: 0.0098 Acc: 0.9972
#
# Epoch 18/29
# ----------
# train Loss: 0.0085 Acc: 0.9986
#
# Epoch 19/29
# ----------
# train Loss: 0.0049 Acc: 1.0000
#
# Epoch 20/29
# ----------
# train Loss: 0.0053 Acc: 0.9993
#
# Epoch 21/29
# ----------
# train Loss: 0.0040 Acc: 0.9993
#
# Epoch 22/29
# ----------
# train Loss: 0.0040 Acc: 0.9993
#
# Epoch 23/29
# ----------
# train Loss: 0.0057 Acc: 0.9986
#
# Epoch 24/29
# ----------
# train Loss: 0.0044 Acc: 0.9993
#
# Epoch 25/29
# ----------
# train Loss: 0.0037 Acc: 0.9993
#
# Epoch 26/29
# ----------
# train Loss: 0.0046 Acc: 0.9993
#
# Epoch 27/29
# ----------
# train Loss: 0.0024 Acc: 1.0000
#
# Epoch 28/29
# ----------
# train Loss: 0.0030 Acc: 1.0000
#
# Epoch 29/29
# ----------
# train Loss: 0.0020 Acc: 1.0000
#
# Training complete in 4m 52s

# %%
vgg11.eval()

df_res = pd.DataFrame(columns=['path', 'acquisition', 'name', 'direction', 'label', 'predicted'])

data_transforms = transforms.Compose([transforms.Resize(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])
                                      ])

for index, row in df_test.iterrows():
  input = row.path
  print('Working on '+ input)

  img = Image.open(input)
  img = data_transforms(img).to(device)
  img = img.unsqueeze_(0)
  outputs = vgg11(img)
  _, predicted = torch.max(outputs, 1)

  res = row.copy()
  res['predicted'] = class_names[predicted.item()]

  df_res = df_res.append(res)
# Out:
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_09_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_BDX.png

# %%
true_label = df_res.label.values
predicted = df_res.predicted.values

print((np.sum((true_label == predicted).astype(int)))/df_res.shape[0])
# Out:
# 0.9536423841059603

# %%
confusion_matrix(true_label, predicted)
# Out:
# array([[131,   9],
#        [  5, 157]])

# %% [markdown]
# ### 4.3.3. GoogLeNet

# %%
model_name = 'googlenet'
num_classes = 2

googlenet_mode = 'fine_tuning'

googlenet, input_size = initialize_model(model_name, num_classes, googlenet_mode, use_pretrained=True)

googlenet_params = []
for name, param in googlenet.named_parameters():
    if param.requires_grad == True:
        googlenet_params.append(param)

googlenet_batch_size = 32
googlenet_num_epochs = 30

googlenet_criterion = nn.CrossEntropyLoss()

googlenet_learning_rate = 0.00001
googlenet_weight_decay = 0
googlenet_optimizer = optim.Adam(googlenet_params, lr=googlenet_learning_rate, weight_decay=googlenet_weight_decay)

googlenet_gamma = 1
googlenet_step_size = 10
googlenet_scheduler = lr_scheduler.StepLR(googlenet_optimizer, step_size=googlenet_step_size, gamma=googlenet_gamma)
# Out:
# Fine tuning: training all the layers

# %%
print(googlenet)
print()
print("Params to learn:")
for name, param in googlenet.named_parameters():
    if param.requires_grad == True:
        print("\t",name)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features
# 	 inception5a.branch2.1.bn.bias
# 	 inception5a.branch3.0.conv.weight
# 	 inception5a.branch3.0.bn.weight
# 	 inception5a.branch3.0.bn.bias
# 	 inception5a.branch3.1.conv.weight
# 	 inception5a.branch3.1.bn.weight
# 	 inception5a.branch3.1.bn.bias
# 	 inception5a.branch4.1.conv.weight
# 	 inception5a.branch4.1.bn.weight
# 	 inception5a.branch4.1.bn.bias
# 	 inception5b.branch1.conv.weight
# 	 inception5b.branch1.bn.weight
# 	 inception5b.branch1.bn.bias
# 	 inception5b.branch2.0.conv.weight
# 	 inception5b.branch2.0.bn.weight
# 	 inception5b.branch2.0.bn.bias
# 	 inception5b.branch2.1.conv.weight
# 	 inception5b.branch2.1.bn.weight
# 	 inception5b.branch2.1.bn.bias
# 	 inception5b.branch3.0.conv.weight
# 	 inception5b.branch3.0.bn.weight
# 	 inception5b.branch3.0.bn.bias
# 	 inception5b.branch3.1.conv.weight
# 	 inception5b.branch3.1.bn.weight
# 	 inception5b.branch3.1.bn.bias
# 	 inception5b.branch4.1.conv.weight
# 	 inception5b.branch4.1.bn.weight
# 	 inception5b.branch4.1.bn.bias
# 	 fc.weight
# 	 fc.bias

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ])
                   }

data_dir = '/content/dataset/modelselect'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=googlenet_batch_size, shuffle=True, num_workers=4) for x in ['train']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1420}
# ['egg', 'empty']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

googlenet = googlenet.to(device)
# Out:
# cuda:0

# %%
googlenet, train_loss, train_acc = train_model(googlenet, dataloaders, googlenet_criterion, googlenet_optimizer, googlenet_scheduler, googlenet_num_epochs)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.5842 Acc: 0.7176
#
# Epoch 1/29
# ----------
# train Loss: 0.3896 Acc: 0.8986
#
# Epoch 2/29
# ----------
# train Loss: 0.2910 Acc: 0.9232
#
# Epoch 3/29
# ----------
# train Loss: 0.2314 Acc: 0.9289
#
# Epoch 4/29
# ----------
# train Loss: 0.1903 Acc: 0.9500
#
# Epoch 5/29
# ----------
# train Loss: 0.1549 Acc: 0.9620
#
# Epoch 6/29
# ----------
# train Loss: 0.1223 Acc: 0.9732
#
# Epoch 7/29
# ----------
# train Loss: 0.1106 Acc: 0.9789
#
# Epoch 8/29
# ----------
# train Loss: 0.0808 Acc: 0.9859
#
# Epoch 9/29
# ----------
# train Loss: 0.0823 Acc: 0.9782
#
# Epoch 10/29
# ----------
# train Loss: 0.0638 Acc: 0.9894
#
# Epoch 11/29
# ----------
# train Loss: 0.0557 Acc: 0.9901
#
# Epoch 12/29
# ----------
# train Loss: 0.0510 Acc: 0.9944
#
# Epoch 13/29
# ----------
# train Loss: 0.0481 Acc: 0.9923
#
# Epoch 14/29
# ----------
# train Loss: 0.0516 Acc: 0.9887
#
# Epoch 15/29
# ----------
# train Loss: 0.0377 Acc: 0.9930
#
# Epoch 16/29
# ----------
# train Loss: 0.0377 Acc: 0.9923
#
# Epoch 17/29
# ----------
# train Loss: 0.0249 Acc: 0.9993
#
# Epoch 18/29
# ----------
# train Loss: 0.0281 Acc: 0.9965
#
# Epoch 19/29
# ----------
# train Loss: 0.0254 Acc: 0.9972
#
# Epoch 20/29
# ----------
# train Loss: 0.0230 Acc: 0.9965
#
# Epoch 21/29
# ----------
# train Loss: 0.0217 Acc: 0.9979
#
# Epoch 22/29
# ----------
# train Loss: 0.0204 Acc: 0.9979
#
# Epoch 23/29
# ----------
# train Loss: 0.0167 Acc: 0.9986
#
# Epoch 24/29
# ----------
# train Loss: 0.0142 Acc: 0.9986
#
# Epoch 25/29
# ----------
# train Loss: 0.0142 Acc: 0.9993
#
# Epoch 26/29
# ----------
# train Loss: 0.0172 Acc: 0.9972
#
# Epoch 27/29
# ----------
# train Loss: 0.0126 Acc: 0.9993
#
# Epoch 28/29
# ----------
# train Loss: 0.0088 Acc: 1.0000
#
# Epoch 29/29
# ----------
# train Loss: 0.0125 Acc: 0.9986
#
# Training complete in 3m 55s

# %%
googlenet.eval()

df_res = pd.DataFrame(columns=['path', 'acquisition', 'name', 'direction', 'label', 'predicted'])

data_transforms = transforms.Compose([transforms.Resize(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])
                                      ])

for index, row in df_test.iterrows():
  input = row.path
  print('Working on '+ input)

  img = Image.open(input)
  img = data_transforms(img).to(device)
  img = img.unsqueeze_(0)
  outputs = googlenet(img)
  _, predicted = torch.max(outputs, 1)

  res = row.copy()
  res['predicted'] = class_names[predicted.item()]

  df_res = df_res.append(res)
# Out:
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_05_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_08_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_04_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_09_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_15_04_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_06_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_10_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_12_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_00_05_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_00_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_01_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_11_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_03_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_13_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_07_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_02_01_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_06_10_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_11_08_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_12_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_14_07_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_09_02_central.png
# Working on /content/dataset/train/empty/Acquisizione6_micro_03_09_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_3_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_13_04_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_11_05_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_3_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_2_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_01_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_11_2_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_03_10_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_1_BDX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_1_central.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_00_09_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_05_07_1_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_02_06_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_08_11_2_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_04_06_2_BSX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_09_1_ASX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_15_05_2_ADX.png
# Working on /content/dataset/train/uovo/Acquisizione6_micro_06_07_2_BDX.png

# %%
true_label = df_res.label.values
predicted = df_res.predicted.values

print((np.sum((true_label == predicted).astype(int)))/df_res.shape[0])
# Out:
# 0.9701986754966887

# %%
confusion_matrix(true_label, predicted)
# Out:
# array([[133,   7],
#        [  2, 160]])

# %% [markdown]
# # 5. Submission
# The best network is GoogLeNet, so we choose it as final model.
#
# Now we can finally create the submission file. To to so, we first train the final model using the whole training set, then we predict the class label for the instances of the (original) test set.

# %%
model_name = 'googlenet'
num_classes = 2

googlenet_mode = 'fine_tuning'

final_googlenet, input_size = initialize_model(model_name, num_classes, googlenet_mode, use_pretrained=True)

googlenet_params = []
for name, param in final_googlenet.named_parameters():
    if param.requires_grad == True:
        googlenet_params.append(param)

googlenet_batch_size = 32
googlenet_num_epochs = 30

googlenet_criterion = nn.CrossEntropyLoss()

googlenet_learning_rate = 0.00001
googlenet_weight_decay = 0
googlenet_optimizer = optim.Adam(googlenet_params, lr=googlenet_learning_rate, weight_decay=googlenet_weight_decay)

googlenet_gamma = 1
googlenet_step_size = 10
googlenet_scheduler = lr_scheduler.StepLR(googlenet_optimizer, step_size=googlenet_step_size, gamma=googlenet_gamma)
# Out:
# Fine tuning: training all the layers

# %%
print(final_googlenet)
print()
print("Params to learn:")
for name, param in final_googlenet.named_parameters():
    if param.requires_grad == True:
        print("\t",name)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=2, bias=True)
# )
#
# Params to learn:
# 	 conv1.conv.weight
# 	 conv1.bn.weight
# 	 conv1.bn.bias
# 	 conv2.conv.weight
# 	 conv2.bn.weight
# 	 conv2.bn.bias
# 	 conv3.conv.weight
# 	 conv3.bn.weight
# 	 conv3.bn.bias
# 	 inception3a.branch1.conv.weight
# 	 inception3a.branch1.bn.weight
# 	 inception3a.branch1.bn.bias
# 	 inception3a.branch2.0.conv.weight
# 	 inception3a.branch2.0.bn.weight
# 	 inception3a.branch2.0.bn.bias
# 	 inception3a.branch2.1.conv.weight
# 	 inception3a.branch2.1.bn.weight
# 	 inception3a.branch2.1.bn.bias
# 	 inception3a.branch3.0.conv.weight
# 	 inception3a.branch3.0.bn.weight
# 	 inception3a.branch3.0.bn.bias
# 	 inception3a.branch3.1.conv.weight
# 	 inception3a.branch3.1.bn.weight
# 	 inception3a.branch3.1.bn.bias
# 	 inception3a.branch4.1.conv.weight
# 	 inception3a.branch4.1.bn.weight
# 	 inception3a.branch4.1.bn.bias
# 	 inception3b.branch1.conv.weight
# 	 inception3b.branch1.bn.weight
# 	 inception3b.branch1.bn.bias
# 	 inception3b.branch2.0.conv.weight
# 	 inception3b.branch2.0.bn.weight
# 	 inception3b.branch2.0.bn.bias
# 	 inception3b.branch2.1.conv.weight
# 	 inception3b.branch2.1.bn.weight
# 	 inception3b.branch2.1.bn.bias
# 	 inception3b.branch3.0.conv.weight
# 	 inception3b.branch3.0.bn.weight
# 	 inception3b.branch3.0.bn.bias
# 	 inception3b.branch3.1.conv.weight
# 	 inception3b.branch3.1.bn.weight
# 	 inception3b.branch3.1.bn.bias
# 	 inception3b.branch4.1.conv.weight
# 	 inception3b.branch4.1.bn.weight
# 	 inception3b.branch4.1.bn.bias
# 	 inception4a.branch1.conv.weight
# 	 inception4a.branch1.bn.weight
# 	 inception4a.branch1.bn.bias
# 	 inception4a.branch2.0.conv.weight
# 	 inception4a.branch2.0.bn.weight
# 	 inception4a.branch2.0.bn.bias
# 	 inception4a.branch2.1.conv.weight
# 	 inception4a.branch2.1.bn.weight
# 	 inception4a.branch2.1.bn.bias
# 	 inception4a.branch3.0.conv.weight
# 	 inception4a.branch3.0.bn.weight
# 	 inception4a.branch3.0.bn.bias
# 	 inception4a.branch3.1.conv.weight
# 	 inception4a.branch3.1.bn.weight
# 	 inception4a.branch3.1.bn.bias
# 	 inception4a.branch4.1.conv.weight
# 	 inception4a.branch4.1.bn.weight
# 	 inception4a.branch4.1.bn.bias
# 	 inception4b.branch1.conv.weight
# 	 inception4b.branch1.bn.weight
# 	 inception4b.branch1.bn.bias
# 	 inception4b.branch2.0.conv.weight
# 	 inception4b.branch2.0.bn.weight
# 	 inception4b.branch2.0.bn.bias
# 	 inception4b.branch2.1.conv.weight
# 	 inception4b.branch2.1.bn.weight
# 	 inception4b.branch2.1.bn.bias
# 	 inception4b.branch3.0.conv.weight
# 	 inception4b.branch3.0.bn.weight
# 	 inception4b.branch3.0.bn.bias
# 	 inception4b.branch3.1.conv.weight
# 	 inception4b.branch3.1.bn.weight
# 	 inception4b.branch3.1.bn.bias
# 	 inception4b.branch4.1.conv.weight
# 	 inception4b.branch4.1.bn.weight
# 	 inception4b.branch4.1.bn.bias
# 	 inception4c.branch1.conv.weight
# 	 inception4c.branch1.bn.weight
# 	 inception4c.branch1.bn.bias
# 	 inception4c.branch2.0.conv.weight
# 	 inception4c.branch2.0.bn.weight
# 	 inception4c.branch2.0.bn.bias
# 	 inception4c.branch2.1.conv.weight
# 	 inception4c.branch2.1.bn.weight
# 	 inception4c.branch2.1.bn.bias
# 	 inception4c.branch3.0.conv.weight
# 	 inception4c.branch3.0.bn.weight
# 	 inception4c.branch3.0.bn.bias
# 	 inception4c.branch3.1.conv.weight
# 	 inception4c.branch3.1.bn.weight
# 	 inception4c.branch3.1.bn.bias
# 	 inception4c.branch4.1.conv.weight
# 	 inception4c.branch4.1.bn.weight
# 	 inception4c.branch4.1.bn.bias
# 	 inception4d.branch1.conv.weight
# 	 inception4d.branch1.bn.weight
# 	 inception4d.branch1.bn.bias
# 	 inception4d.branch2.0.conv.weight
# 	 inception4d.branch2.0.bn.weight
# 	 inception4d.branch2.0.bn.bias
# 	 inception4d.branch2.1.conv.weight
# 	 inception4d.branch2.1.bn.weight
# 	 inception4d.branch2.1.bn.bias
# 	 inception4d.branch3.0.conv.weight
# 	 inception4d.branch3.0.bn.weight
# 	 inception4d.branch3.0.bn.bias
# 	 inception4d.branch3.1.conv.weight
# 	 inception4d.branch3.1.bn.weight
# 	 inception4d.branch3.1.bn.bias
# 	 inception4d.branch4.1.conv.weight
# 	 inception4d.branch4.1.bn.weight
# 	 inception4d.branch4.1.bn.bias
# 	 inception4e.branch1.conv.weight
# 	 inception4e.branch1.bn.weight
# 	 inception4e.branch1.bn.bias
# 	 inception4e.branch2.0.conv.weight
# 	 inception4e.branch2.0.bn.weight
# 	 inception4e.branch2.0.bn.bias
# 	 inception4e.branch2.1.conv.weight
# 	 inception4e.branch2.1.bn.weight
# 	 inception4e.branch2.1.bn.bias
# 	 inception4e.branch3.0.conv.weight
# 	 inception4e.branch3.0.bn.weight
# 	 inception4e.branch3.0.bn.bias
# 	 inception4e.branch3.1.conv.weight
# 	 inception4e.branch3.1.bn.weight
# 	 inception4e.branch3.1.bn.bias
# 	 inception4e.branch4.1.conv.weight
# 	 inception4e.branch4.1.bn.weight
# 	 inception4e.branch4.1.bn.bias
# 	 inception5a.branch1.conv.weight
# 	 inception5a.branch1.bn.weight
# 	 inception5a.branch1.bn.bias
# 	 inception5a.branch2.0.conv.weight
# 	 inception5a.branch2.0.bn.weight
# 	 inception5a.branch2.0.bn.bias
# 	 inception5a.branch2.1.conv.weight
# 	 inception5a.branch2.1.bn.weight
# 	 inception5a.branch2.1.bn.bias
# 	 inception5a.branch3.0.conv.weight
# 	 inception5a.branch3.0.bn.weight
# 	 inception5a.branch3.0.bn.bias
# 	 inception5a.branch3.1.conv.weight
# 	 inception5a.branch3.1.bn.weight
# 	 inception5a.branch3.1.bn.bias
# 	 inception5a.branch4.1.conv.weight
# 	 inception5a.branch4.1.bn.weight
# 	 inception5a.branch4.1.bn.bias
# 	 inception5b.branch1.conv.weight
# 	 inception5b.branch1.bn.weight
# 	 inception5b.branch1.bn.bias
# 	 inception5b.branch2.0.conv.weight
# 	 inception5b.branch2.0.bn.weight
# 	 inception5b.branch2.0.bn.bias
# 	 inception5b.branch2.1.conv.weight
# 	 inception5b.branch2.1.bn.weight
# 	 inception5b.branch2.1.bn.bias
# 	 inception5b.branch3.0.conv.weight
# 	 inception5b.branch3.0.bn.weight
# 	 inception5b.branch3.0.bn.bias
# 	 inception5b.branch3.1.conv.weight
# 	 inception5b.branch3.1.bn.weight
# 	 inception5b.branch3.1.bn.bias
# 	 inception5b.branch4.1.conv.weight
# 	 inception5b.branch4.1.bn.weight
# 	 inception5b.branch4.1.bn.bias
# 	 fc.weight
# 	 fc.bias

# %%
data_transforms = {'train':transforms.Compose([transforms.Resize(224),
                                               transforms.RandomHorizontalFlip(),
                                               transforms.RandomVerticalFlip(),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], 
                                                                    [0.229, 0.224, 0.225])
                                               ])
                   }

data_dir = '/content/dataset'

image_datasets = {x : datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=googlenet_batch_size, shuffle=True, num_workers=4) for x in ['train']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train']}
class_names = image_datasets['train'].classes
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 1722}
# ['empty', 'uovo']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

final_googlenet = final_googlenet.to(device)
# Out:
# cuda:0

# %% [markdown]
# Train the model using the whole training set.

# %%
final_googlenet, train_loss, train_acc = train_model(final_googlenet, dataloaders, googlenet_criterion, googlenet_optimizer, googlenet_scheduler, googlenet_num_epochs)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.5806 Acc: 0.7305
#
# Epoch 1/29
# ----------
# train Loss: 0.4034 Acc: 0.8769
#
# Epoch 2/29
# ----------
# train Loss: 0.2965 Acc: 0.9094
#
# Epoch 3/29
# ----------
# train Loss: 0.2250 Acc: 0.9355
#
# Epoch 4/29
# ----------
# train Loss: 0.1803 Acc: 0.9553
#
# Epoch 5/29
# ----------
# train Loss: 0.1428 Acc: 0.9634
#
# Epoch 6/29
# ----------
# train Loss: 0.1144 Acc: 0.9768
#
# Epoch 7/29
# ----------
# train Loss: 0.0930 Acc: 0.9808
#
# Epoch 8/29
# ----------
# train Loss: 0.0767 Acc: 0.9866
#
# Epoch 9/29
# ----------
# train Loss: 0.0771 Acc: 0.9803
#
# Epoch 10/29
# ----------
# train Loss: 0.0608 Acc: 0.9895
#
# Epoch 11/29
# ----------
# train Loss: 0.0568 Acc: 0.9872
#
# Epoch 12/29
# ----------
# train Loss: 0.0528 Acc: 0.9855
#
# Epoch 13/29
# ----------
# train Loss: 0.0517 Acc: 0.9872
#
# Epoch 14/29
# ----------
# train Loss: 0.0379 Acc: 0.9942
#
# Epoch 15/29
# ----------
# train Loss: 0.0334 Acc: 0.9959
#
# Epoch 16/29
# ----------
# train Loss: 0.0288 Acc: 0.9959
#
# Epoch 17/29
# ----------
# train Loss: 0.0350 Acc: 0.9919
#
# Epoch 18/29
# ----------
# train Loss: 0.0254 Acc: 0.9965
#
# Epoch 19/29
# ----------
# train Loss: 0.0286 Acc: 0.9959
#
# Epoch 20/29
# ----------
# train Loss: 0.0230 Acc: 0.9954
#
# Epoch 21/29
# ----------
# train Loss: 0.0252 Acc: 0.9954
#
# Epoch 22/29
# ----------
# train Loss: 0.0167 Acc: 0.9983
#
# Epoch 23/29
# ----------
# train Loss: 0.0167 Acc: 0.9971
#
# Epoch 24/29
# ----------
# train Loss: 0.0170 Acc: 0.9971
#
# Epoch 25/29
# ----------
# train Loss: 0.0156 Acc: 0.9977
#
# Epoch 26/29
# ----------
# train Loss: 0.0151 Acc: 0.9983
#
# Epoch 27/29
# ----------
# train Loss: 0.0150 Acc: 0.9977
#
# Epoch 28/29
# ----------
# train Loss: 0.0150 Acc: 0.9977
#
# Epoch 29/29
# ----------
# train Loss: 0.0104 Acc: 0.9994
#
# Training complete in 4m 39s

# %% [markdown]
# Save the final model trained

# %%
model_path = 'drive/MyDrive/Colab Notebooks/DM - Collab/Mini Contest 3/models/model_googlenet.pth'
torch.save(final_googlenet.state_dict(), model_path)

# %% [markdown]
# Predict class label of the test images.

# %%
final_googlenet.eval()

df_sub = pd.DataFrame(columns=['ID', 'Class'])

data_transforms = transforms.Compose([transforms.Resize(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])
                                      ])

test_dir = '/content/dataset/test/'

for entry in test:
  print('Working on '+ entry)

  img = Image.open(test_dir + entry)
  img = data_transforms(img).to(device)
  img = img.unsqueeze_(0)
  outputs = final_googlenet(img)
  _, predicted = torch.max(outputs, 1)

  id = entry.split('.')[0]
  label = class_names[predicted.item()]
  row = {'ID':[id], 'Class':[label]}

  df_sub = df_sub.append(pd.DataFrame(row))
# Out:
# Working on 4_7.png
# Working on 2_268.png
# Working on 4_6.png
# Working on 4_225.png
# Working on 4_350.png
# Working on 4_184.png
# Working on 4_49.png
# Working on 4_78.png
# Working on 4_194.png
# Working on 4_240.png
# Working on 4_254.png
# Working on 2_56.png
# Working on 2_33.png
# Working on 2_124.png
# Working on 4_335.png
# Working on 4_197.png
# Working on 4_44.png
# Working on 2_104.png
# Working on 4_122.png
# Working on 4_135.png
# Working on 2_147.png
# Working on 2_309.png
# Working on 4_218.png
# Working on 4_31.png
# Working on 4_105.png
# Working on 4_276.png
# Working on 4_11.png
# Working on 2_76.png
# Working on 4_110.png
# Working on 4_284.png
# Working on 4_209.png
# Working on 4_185.png
# Working on 2_49.png
# Working on 2_229.png
# Working on 4_160.png
# Working on 2_278.png
# Working on 4_325.png
# Working on 4_356.png
# Working on 2_231.png
# Working on 2_35.png
# Working on 4_174.png
# Working on 2_110.png
# Working on 2_23.png
# Working on 2_174.png
# Working on 4_318.png
# Working on 4_264.png
# Working on 2_88.png
# Working on 2_301.png
# Working on 4_304.png
# Working on 2_185.png
# Working on K_15.png
# Working on K_1.png
# Working on 2_205.png
# Working on 4_214.png
# Working on 4_196.png
# Working on 4_247.png
# Working on 2_156.png
# Working on 4_308.png
# Working on 4_319.png
# Working on 2_1.png
# Working on 4_204.png
# Working on 4_313.png
# Working on 4_108.png
# Working on 4_83.png
# Working on 4_17.png
# Working on 2_287.png
# Working on 2_253.png
# Working on 2_93.png
# Working on 2_32.png
# Working on 2_63.png
# Working on 2_52.png
# Working on 4_354.png
# Working on 2_105.png
# Working on 4_50.png
# Working on 2_193.png
# Working on 4_64.png
# Working on 4_182.png
# Working on 4_190.png
# Working on 4_66.png
# Working on 2_319.png
# Working on 2_57.png
# Working on 4_351.png
# Working on 2_273.png
# Working on 2_37.png
# Working on 2_240.png
# Working on 2_11.png
# Working on 4_10.png
# Working on 2_244.png
# Working on K_9.png
# Working on 4_235.png
# Working on 2_315.png
# Working on 2_126.png
# Working on 4_159.png
# Working on K_10.png
# Working on K_25.png
# Working on 2_68.png
# Working on 2_217.png
# Working on 2_107.png
# Working on 2_12.png
# Working on 4_89.png
# Working on 2_44.png
# Working on 4_51.png
# Working on 2_146.png
# Working on 2_266.png
# Working on 2_243.png
# Working on 2_15.png
# Working on 2_295.png
# Working on 4_361.png
# Working on 4_233.png
# Working on 4_69.png
# Working on 4_222.png
# Working on K_34.png
# Working on 2_228.png
# Working on 2_42.png
# Working on 4_79.png
# Working on 4_248.png
# Working on 4_343.png
# Working on 4_112.png
# Working on 2_325.png
# Working on 2_84.png
# Working on 2_108.png
# Working on K_24.png
# Working on 4_251.png
# Working on 2_102.png
# Working on 2_307.png
# Working on K_23.png
# Working on 2_39.png
# Working on 2_41.png
# Working on 4_288.png
# Working on 2_114.png
# Working on K_19.png
# Working on 4_300.png
# Working on 4_139.png
# Working on 2_140.png
# Working on 4_252.png
# Working on 4_337.png
# Working on 2_234.png
# Working on 2_14.png
# Working on 2_20.png
# Working on 2_118.png
# Working on 2_277.png
# Working on K_33.png
# Working on 2_129.png
# Working on 4_332.png
# Working on 4_106.png
# Working on 4_99.png
# Working on 2_120.png
# Working on 2_152.png
# Working on 4_267.png
# Working on 4_81.png
# Working on 2_259.png
# Working on 2_8.png
# Working on K_16.png
# Working on 2_235.png
# Working on K_37.png
# Working on 4_243.png
# Working on 4_309.png
# Working on 2_101.png
# Working on 4_277.png
# Working on 4_76.png
# Working on 4_346.png
# Working on 2_34.png
# Working on 4_283.png
# Working on 2_148.png
# Working on 4_289.png
# Working on 4_238.png
# Working on 2_91.png
# Working on 4_201.png
# Working on 2_222.png
# Working on 2_36.png
# Working on 2_201.png
# Working on K_2.png
# Working on 4_293.png

# %% [markdown]
# We can look at the class distribution of the test instances.

# %%
df_sub.groupby('Class').ID.count().plot.barh()
plt.show()

# %%
sub_path = 'drive/MyDrive/Colab Notebooks/DM - Collab/Mini Contest 3/submission/sub_googlenet.csv'
df_sub.to_csv(sub_path, index=False)

# %% [markdown]
# In the private leaderboard of Kaggle's competition we can see that model's accuracy is 0.98897, which means that in the previous section we found an accurate estimation.
